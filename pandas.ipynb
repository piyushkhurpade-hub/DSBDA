# %%
import pandas as pd

# %%
df = pd.DataFrame(
    {
        "a": [4,5,6],
        "b": [7,8,9],
        "c": [10,11,12]
    },
    index=[1,2,3]
)

df = pd.DataFrame(
[[4, 7, 10],
[5, 8, 11],
[6, 9, 12]],
index=[1, 2, 3],
columns=['a', 'b', 'c'])

# %%
df = pd.DataFrame( {
    "Name": ["piyush", "shanku", "nikhil"],
    "Age": [21,20,25],
    "Location": ["Mumbai", "Pune", "Nagpur"]
    
},
    index=[1,2,3]
)

# %%
df
# Out:
#      Name  Age Location
# 1  piyush   21   Mumbai
# 2  shanku   20     Pune
# 3  nikhil   25   Nagpur

# %%
df.head()
# Out:
#      Name  Age Location
# 1  piyush   21   Mumbai
# 2  shanku   20     Pune
# 3  nikhil   25   Nagpur

# %%
df.tail()
# Out:
#      Name  Age Location
# 1  piyush   21   Mumbai
# 2  shanku   20     Pune
# 3  nikhil   25   Nagpur

# %%
df.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 1 to 3
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      3 non-null      object
#  1   Age       3 non-null      int64
#  2   Location  3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 72.0+ bytes

# %%
df.describe()
# Out:
#              Age
# count   3.000000
# mean   22.000000
# std     2.645751
# min    20.000000
# 25%    20.500000
# 50%    21.000000
# 75%    23.000000
# max    25.000000

# %%
df['Age'].max()
# Out:
# np.int64(25)

# %%
df['Age'].min()
# Out:
# np.int64(20)

# %%
df['Age'].mean()
# Out:
# np.float64(22.0)

# %%
df.drop_duplicates()
# Out:
#      Name  Age Location
# 1  piyush   21   Mumbai
# 2  shanku   20     Pune
# 3  nikhil   25   Nagpur

# %%
df = pd.DataFrame( {
    "Name": ["piyush", "shanku", "nikhil", "jony"],
    "Age": [21,20,25,35],
    "Location": ["Mumbai", "Pune", "Nagpur","America"]
    
},
    index=[1,2,3,4]
)

# %%
df
# Out:
#      Name  Age Location
# 1  piyush   21   Mumbai
# 2  shanku   20     Pune
# 3  nikhil   25   Nagpur
# 4    jony   35  America

# %%
df.drop_duplicates()
# Out:
#      Name  Age Location
# 1  piyush   21   Mumbai
# 2  shanku   20     Pune
# 3  nikhil   25   Nagpur
# 4    jony   35  America

# %%
df.loc[2]
# Out:
# Name        shanku
# Age             20
# Location      Pune
# Name: 2, dtype: object

# %%
df.iloc[0:]
# Out:
#      Name  Age Location
# 1  piyush   21   Mumbai
# 2  shanku   20     Pune
# 3  nikhil   25   Nagpur
# 4    jony   35  America

# %%
df.drop(3)
# Out:
#      Name  Age Location
# 1  piyush   21   Mumbai
# 2  shanku   20     Pune
# 4    jony   35  America

# %%
df[df.Age<25]
# Out:
#      Name  Age Location
# 1  piyush   21   Mumbai
# 2  shanku   20     Pune

# %%
df.isnull()
# Out:
#     Name    Age  Location
# 1  False  False     False
# 2  False  False     False
# 3  False  False     False
# 4  False  False     False
